# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import zscore
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, ShuffleSplit
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

# %%
# Alter the file path as you see fit
df = pd.read_csv('Cleaned Train.csv')
df.head()
# Out:
#        ID  Month  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0  0x1602      1   23          12       19114.12            1824.843333
# 1  0x1603      2   23          12       19114.12            1824.843333
# 2  0x1604      3   23          12       19114.12            1824.843333
# 3  0x1605      4   23          12       19114.12            1824.843333
# 4  0x1606      5   23          12       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3            4
# 1                  3                4              3            4
# 2                  3                4              3            4
# 3                  3                4              3            4
# 4                  3                4              3            4
#
#    Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                    3                       7                 11.27
# 1                    3                       4                 11.27
# 2                    3                       7                 11.27
# 3                    5                       4                  6.27
# 4                    6                       4                 11.27
#
#    Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# 0                     4           1            809.98
# 1                     4           1            809.98
# 2                     4           1            809.98
# 3                     4           1            809.98
# 4                     4           1            809.98
#
#    Credit_Utilization_Ratio  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                 26.822620                      1            49.574949
# 1                 31.944960                      1            49.574949
# 2                 28.609352                      1            49.574949
# 3                 31.377862                      1            49.574949
# 4                 24.797347                      1            49.574949
#
#    Amount_invested_monthly  Payment_Behaviour  Monthly_Balance  Credit_Score
# 0                80.415295                  3       312.494089             2
# 1               118.280222                  4       284.629162             2
# 2                81.699521                  5       331.209863             2
# 3               199.458074                  6       223.451310             2
# 4                41.420153                  2       341.489231             2

# %%
df.set_index('ID', drop=True, inplace=True)

X = df.drop('Credit_Score', axis=1)
y = df[['Credit_Score']]
y1 = y.copy()
y['Credit_Score'] = y['Credit_Score'].astype('category')

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0x1602 to 0x25fed
# Data columns (total 1 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Credit_Score  100000 non-null  category
# dtypes: category(1)
# memory usage: 879.0+ KB

# %%
y.head()
# Out:
#        Credit_Score
# ID
# 0x1602            2
# 0x1603            2
# 0x1604            2
# 0x1605            2
# 0x1606            2

# %%
y['Credit_Score'].value_counts(normalize=True)*100
# Out:
# 1    53.174
# 0    28.998
# 2    17.828
# Name: Credit_Score, dtype: float64

# %%
# Converting Cateogry columns to 'category' data type
cat_col = ['Month', 'Occupation', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']
for i in cat_col:
    X[i] = X[i].astype('category')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0x1602 to 0x25fed
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  category
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  category
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Delay_from_due_date       100000 non-null  int64
#  10  Num_of_Delayed_Payment    100000 non-null  int64
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  int64
#  13  Credit_Mix                100000 non-null  category
#  14  Outstanding_Debt          100000 non-null  float64
#  15  Credit_Utilization_Ratio  100000 non-null  float64
#  16  Payment_of_Min_Amount     100000 non-null  category
#  17  Total_EMI_per_month       100000 non-null  float64
#  18  Amount_invested_monthly   100000 non-null  float64
#  19  Payment_Behaviour         100000 non-null  category
#  20  Monthly_Balance           100000 non-null  float64
# dtypes: category(5), float64(8), int64(8)
# memory usage: 13.4+ MB

# %%
X.describe().T
# Out:
#                              count          mean           std          min  \
# Age                       100000.0     33.316340     10.764812    14.000000
# Annual_Income             100000.0  50505.123449  38299.422093  7005.930000
# Monthly_Inhand_Salary     100000.0   4197.393268   3186.540184   303.645417
# Num_Bank_Accounts         100000.0      5.367120      2.593856    -1.000000
# Num_Credit_Card           100000.0      5.532240      2.068324     0.000000
# Interest_Rate             100000.0     14.532080      8.741330     1.000000
# Num_of_Loan               100000.0      3.532880      2.446356     0.000000
# Delay_from_due_date       100000.0     21.090050     14.829336    -1.000000
# Num_of_Delayed_Payment    100000.0     13.319690      6.224760     0.000000
# Changed_Credit_Limit      100000.0     10.472003      6.657893     0.000000
# Num_Credit_Inquiries      100000.0      5.798250      3.867826     0.000000
# Outstanding_Debt          100000.0   1426.220376   1155.129026     0.230000
# Credit_Utilization_Ratio  100000.0     32.285173      5.116875    20.000000
# Total_EMI_per_month       100000.0   1403.118217   8306.041270     0.000000
# Amount_invested_monthly   100000.0    193.278093    194.020514     0.000000
# Monthly_Balance           100000.0    403.568326    214.380866     0.007760
#
#                                    25%           50%           75%  \
# Age                          24.000000     33.000000     42.000000
# Annual_Income             19342.972500  36999.705000  71683.470000
# Monthly_Inhand_Salary      1626.594167   3095.905000   5957.715000
# Num_Bank_Accounts             3.000000      5.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 7.000000     13.000000     20.000000
# Num_of_Loan                   2.000000      3.000000      5.000000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Changed_Credit_Limit          5.370000      9.400000     14.850000
# Num_Credit_Inquiries          3.000000      5.000000      8.000000
# Outstanding_Debt            566.072500   1166.155000   1945.962500
# Credit_Utilization_Ratio     28.052567     32.305784     36.496663
# Total_EMI_per_month          30.306660     69.249473    161.224249
# Amount_invested_monthly      73.905176    129.415013    234.393007
# Monthly_Balance             270.368677    337.370828    472.098940
#
#                                     max
# Age                           56.000000
# Annual_Income             179987.280000
# Monthly_Inhand_Salary      15204.633333
# Num_Bank_Accounts             11.000000
# Num_Credit_Card               11.000000
# Interest_Rate                 34.000000
# Num_of_Loan                    9.000000
# Delay_from_due_date           67.000000
# Num_of_Delayed_Payment        25.000000
# Changed_Credit_Limit          36.970000
# Num_Credit_Inquiries          17.000000
# Outstanding_Debt            4998.070000
# Credit_Utilization_Ratio      50.000000
# Total_EMI_per_month        82331.000000
# Amount_invested_monthly     1977.326102
# Monthly_Balance             1602.040519

# %% [markdown]
# ### Let's look at Cross Validation accuracy scores for various Classifiers without Hypertuning any parameters

# %%
print('Random Forest =',np.mean(cross_val_score(RandomForestClassifier(max_depth=7, min_samples_leaf=3), X, y, scoring='accuracy',)))
print('Gradient Boosting =',np.mean(cross_val_score(GradientBoostingClassifier(max_depth=7, min_samples_leaf=3), X, y, cv=3, scoring='accuracy')))
print('XG Boosting =',np.mean(cross_val_score(XGBClassifier(enable_categorical=True), X, y1, scoring='accuracy')))
# Out:
# Random Forest = 0.69738
# Gradient Boosting = 0.7045800625402907
# XG Boosting = 0.6991299999999999

# %% [markdown]
# ### As we can see, simple classifiers aren't giving good accuracies on data. Let's proceed to hypertune the parameters.

# %% [markdown]
# ### Training the models below with all the 100,000 records was computationally very intensive so we have splitted this Train data again to train-test datasets. We will be hypertuning the models with this sub-train set.

# %%
# 85:15 split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ## 1. Random Forest

# %%
RandomForestClassifier().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
shuffle_split = ShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

param_grid = {'n_estimators': [100, 150, 200],
              'criterion': ['gini', 'entropy'],
              'max_depth': [3, 5, 7],
              'max_features': ['sqrt', len(X.columns)],
              'min_samples_leaf': [6, 7, 8, 9, 10],
              'oob_score': [True, False]}

rand_search2 = RandomizedSearchCV(RandomForestClassifier(), param_grid, scoring='accuracy', n_iter=100, verbose=2, cv=shuffle_split, random_state=42)
rand_search2.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=8, n_estimators=150, oob_score=True; total time=  42.1s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=8, n_estimators=100, oob_score=True; total time=  24.7s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=150, oob_score=False; total time= 1.1min
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=150, oob_score=True; total time=  20.0s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=True; total time=  35.0s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=6, n_estimators=150, oob_score=True; total time= 1.1min
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=150, oob_score=False; total time=   8.0s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=False; total time=  33.2s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=7, n_estimators=150, oob_score=True; total time=  15.6s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200, oob_score=True; total time=  23.3s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=200, oob_score=True; total time=  17.4s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=100, oob_score=True; total time= 1.0min
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=  28.8s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=150, oob_score=False; total time= 1.5min
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=200, oob_score=False; total time= 1.2min
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=100, oob_score=True; total time=  11.0s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=9, n_estimators=200, oob_score=False; total time=  13.9s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=  13.4s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=False; total time=  10.4s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=True; total time= 1.5min
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=150, oob_score=True; total time=  17.0s
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=8, n_estimators=100, oob_score=True; total time=  27.8s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=True; total time=  13.8s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=6, n_estimators=150, oob_score=False; total time=  34.6s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=False; total time= 1.1min
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=7, n_estimators=200, oob_score=True; total time= 1.0min
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=150, oob_score=False; total time=  16.8s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=False; total time=  13.2s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=False; total time=   5.5s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=100, oob_score=False; total time=   8.9s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=150, oob_score=False; total time=  16.6s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=7, n_estimators=150, oob_score=False; total time=   7.8s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=200, oob_score=False; total time= 2.0min
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=200, oob_score=True; total time=  23.1s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=200, oob_score=False; total time= 1.2min
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=7, n_estimators=150, oob_score=False; total time=  34.5s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=9, n_estimators=200, oob_score=True; total time=  12.6s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=9, n_estimators=150, oob_score=False; total time= 1.5min
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=6, n_estimators=200, oob_score=True; total time= 1.2min
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=  36.9s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=   6.8s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=  23.5s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200, oob_score=False; total time=  26.6s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=100, oob_score=True; total time=  38.1s
# [CV] END criterion=gini, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=100, oob_score=False; total time=  49.3s
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=9, n_estimators=200, oob_score=True; total time=  57.8s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=10, n_estimators=100, oob_score=False; total time=  21.8s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=6, n_estimators=200, oob_score=False; total time=  11.1s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=8, n_estimators=150, oob_score=False; total time=  34.0s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=100, oob_score=True; total time= 1.0min
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=200, oob_score=True; total time= 1.5min
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=False; total time=  41.3s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=200, oob_score=False; total time=  12.7s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=True; total time=   9.8s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=6, n_estimators=150, oob_score=False; total time= 1.5min
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=100, oob_score=False; total time=  45.0s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=6, n_estimators=150, oob_score=False; total time=   7.5s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=150, oob_score=True; total time=  56.5s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=200, oob_score=True; total time=  18.6s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=150, oob_score=True; total time= 1.1min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=150, oob_score=False; total time=  12.4s
# [CV] END criterion=gini, max_depth=3, max_features=21, min_samples_leaf=8, n_estimators=200, oob_score=True; total time=  46.5s
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=6, n_estimators=100, oob_score=False; total time=  27.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=200, oob_score=False; total time=  17.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=100, oob_score=True; total time=   9.5s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=True; total time=   9.2s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=200, oob_score=True; total time= 2.0min
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=False; total time=   7.1s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=6, n_estimators=200, oob_score=True; total time= 2.0min
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=6, n_estimators=150, oob_score=False; total time=  53.6s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=True; total time=   6.4s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=200, oob_score=False; total time=  12.8s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=100, oob_score=False; total time=  44.0s
# [CV] END criterion=entropy, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=100, oob_score=True; total time= 1.0min
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=9, n_estimators=150, oob_score=False; total time=  41.0s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=150, oob_score=False; total time=  12.3s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=150, oob_score=True; total time=  10.8s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=True; total time=  13.5s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=200, oob_score=True; total time=  12.4s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=7, n_estimators=100, oob_score=True; total time=   8.3s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=100, oob_score=True; total time=  11.8s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=7, n_estimators=100, oob_score=False; total time=   5.6s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=100, oob_score=True; total time=   7.9s
# [CV] END criterion=gini, max_depth=7, max_features=21, min_samples_leaf=6, n_estimators=150, oob_score=True; total time= 1.3min
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=200, oob_score=False; total time=  26.3s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=150, oob_score=True; total time=  20.3s
# [CV] END criterion=gini, max_depth=7, max_features=21, min_samples_leaf=9, n_estimators=200, oob_score=False; total time= 1.6min
# [CV] END criterion=gini, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=150, oob_score=True; total time= 1.3min
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=100, oob_score=False; total time=  36.1s
# [CV] END criterion=entropy, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=100, oob_score=False; total time=  43.3s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100, oob_score=True; total time=   9.0s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=100, oob_score=True; total time=  35.6s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=100, oob_score=True; total time=  11.9s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=150, oob_score=True; total time=  54.4s
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=7, n_estimators=150, oob_score=True; total time=  41.1s
# [CV] END criterion=entropy, max_depth=3, max_features=21, min_samples_leaf=9, n_estimators=100, oob_score=False; total time=  26.9s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=8, n_estimators=200, oob_score=False; total time=  10.9s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=False; total time=  10.9s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=100, oob_score=True; total time=   5.5s
# [CV] END criterion=gini, max_depth=5, max_features=21, min_samples_leaf=7, n_estimators=200, oob_score=False; total time= 1.2min
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=1, random_state=42, test_size=0.2, train_size=None),
#                    estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 7],
#                                         'max_features': ['sqrt', 21],
#                                         'min_samples_leaf': [6, 7, 8, 9, 10],
#                                         'n_estimators': [100, 150, 200],
#                                         'oob_score': [True, False]},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
rand_search2.best_params_
# Out:
# {'oob_score': False,
#  'n_estimators': 100,
#  'min_samples_leaf': 7,
#  'max_features': 21,
#  'max_depth': 7,
#  'criterion': 'gini'}

# %%
# Defining a dataframe to add all accuracies of different models
a = pd.DataFrame(columns=['Model', 'Performance on Sub-Test set', 'Accuracy of CV on Entire Train set'])

# Let's look at performance on test set
model_rf = rand_search2.best_estimator_
model_rf.fit(X_train, y_train)
a2 = model_rf.score(X_test, y_test)

# %%
# Let's look at Cross Validation score
model_rf = rand_search2.best_estimator_
b2 = cross_val_score(model_rf, X, y, cv=5, scoring='accuracy')
b2
# Out:
# array([0.7039, 0.7051, 0.716 , 0.7038, 0.7246])

# %%
print('Mean Accuracy from Cross Validation =',np.mean(b2))
a.loc[len(a.index)] = ['Random Forest', round(a2, 2), round(np.mean(b2), 2)]
# Out:
# Mean Accuracy from Cross Validation = 0.7106800000000001

# %% [markdown]
# ## 2. Gradient Boosting

# %%
GradientBoostingClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'log_loss',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_grid = {'n_estimators': [100, 150, 200],
              'criterion': ['log_loss', 'exponential'],
              'max_depth': [5, 7, 9],
              'max_features': ['sqrt', len(X.columns)],
              'min_samples_leaf': [7, 8, 9, 10],
              'criterion': ['friedman_mse', 'squared_error'],
              'validation_fraction': [0.1, 0.2, 0.3]}

rand_search4 = RandomizedSearchCV(GradientBoostingClassifier(), param_grid, scoring='accuracy', n_iter=100, cv=shuffle_split, verbose=2, random_state=42)
rand_search4.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=100, validation_fraction=0.2; total time= 4.6min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=150, validation_fraction=0.1; total time= 1.3min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=21, min_samples_leaf=7, n_estimators=100, validation_fraction=0.1; total time= 4.6min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time=  56.7s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 1.6min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=150, validation_fraction=0.3; total time= 4.1min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.1; total time= 4.8min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.2; total time= 1.1min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=21, min_samples_leaf=8, n_estimators=200, validation_fraction=0.1; total time= 9.6min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=7, n_estimators=150, validation_fraction=0.2; total time= 1.7min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time= 1.2min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=200, validation_fraction=0.2; total time= 5.6min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.2; total time= 4.8min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.2; total time= 4.0min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=7, n_estimators=150, validation_fraction=0.1; total time= 4.3min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=100, validation_fraction=0.3; total time= 1.1min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.2; total time= 1.7min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=100, validation_fraction=0.1; total time=  52.2s
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time=  38.3s
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=100, validation_fraction=0.2; total time= 2.7min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=200, validation_fraction=0.2; total time= 5.4min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time=  40.9s
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time= 7.3min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.2; total time= 2.7min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=100, validation_fraction=0.2; total time= 3.7min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.3; total time= 3.7min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=8, n_estimators=150, validation_fraction=0.2; total time= 1.7min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.2; total time= 1.6min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=200, validation_fraction=0.2; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time= 1.3min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.1; total time= 3.7min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=7, n_estimators=150, validation_fraction=0.1; total time= 7.3min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=200, validation_fraction=0.2; total time= 1.8min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.1; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.2; total time= 7.2min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=150, validation_fraction=0.3; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=8, n_estimators=150, validation_fraction=0.3; total time= 1.7min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 5.6min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=200, validation_fraction=0.2; total time= 1.7min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 6.8min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=100, validation_fraction=0.2; total time= 3.5min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time=  50.6s
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=200, validation_fraction=0.1; total time= 1.6min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=100, validation_fraction=0.2; total time=  50.3s
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=200, validation_fraction=0.1; total time= 1.2min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=200, validation_fraction=0.3; total time= 7.3min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.3; total time=  52.4s
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=150, validation_fraction=0.2; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time=  58.7s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=9, n_estimators=100, validation_fraction=0.2; total time= 1.1min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=200, validation_fraction=0.1; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.2; total time=  57.6s
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 5.4min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=7, n_estimators=100, validation_fraction=0.1; total time=  37.3s
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=100, validation_fraction=0.2; total time=  37.3s
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=200, validation_fraction=0.2; total time= 5.3min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=200, validation_fraction=0.1; total time= 5.3min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.3; total time= 2.7min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=200, validation_fraction=0.2; total time= 2.2min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=100, validation_fraction=0.2; total time=  51.2s
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.2; total time= 5.5min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 3.9min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=200, validation_fraction=0.2; total time= 1.7min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=100, validation_fraction=0.1; total time=  50.7s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=7, n_estimators=200, validation_fraction=0.2; total time= 2.2min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=200, validation_fraction=0.2; total time= 1.2min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 1.6min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=21, min_samples_leaf=7, n_estimators=150, validation_fraction=0.2; total time= 6.9min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=7, n_estimators=200, validation_fraction=0.3; total time= 2.2min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=7, n_estimators=200, validation_fraction=0.1; total time= 5.2min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time= 3.7min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=9, n_estimators=200, validation_fraction=0.1; total time= 9.5min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.3; total time= 1.3min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=9, n_estimators=200, validation_fraction=0.1; total time= 2.2min
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=100, validation_fraction=0.1; total time= 4.6min
# [CV] END criterion=squared_error, max_depth=7, max_features=21, min_samples_leaf=9, n_estimators=100, validation_fraction=0.1; total time= 3.6min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.2; total time=  55.9s
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.2; total time= 2.6min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=sqrt, min_samples_leaf=10, n_estimators=100, validation_fraction=0.2; total time= 1.1min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=7, n_estimators=150, validation_fraction=0.3; total time= 5.4min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.2; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=9, n_estimators=150, validation_fraction=0.1; total time= 1.6min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=9, n_estimators=150, validation_fraction=0.1; total time= 3.9min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=8, n_estimators=200, validation_fraction=0.2; total time= 7.3min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=9, n_estimators=200, validation_fraction=0.1; total time= 1.2min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=200, validation_fraction=0.3; total time= 1.3min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time= 3.9min
# [CV] END criterion=friedman_mse, max_depth=7, max_features=21, min_samples_leaf=9, n_estimators=200, validation_fraction=0.1; total time= 7.1min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=200, validation_fraction=0.1; total time= 1.2min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=150, validation_fraction=0.2; total time=  54.7s
# [CV] END criterion=friedman_mse, max_depth=7, max_features=sqrt, min_samples_leaf=8, n_estimators=150, validation_fraction=0.1; total time= 1.3min
# [CV] END criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=7, n_estimators=200, validation_fraction=0.3; total time= 1.6min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=10, n_estimators=200, validation_fraction=0.3; total time= 5.1min
# [CV] END criterion=squared_error, max_depth=5, max_features=sqrt, min_samples_leaf=8, n_estimators=150, validation_fraction=0.2; total time=  55.7s
# [CV] END criterion=squared_error, max_depth=9, max_features=21, min_samples_leaf=9, n_estimators=150, validation_fraction=0.2; total time= 6.8min
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=9, n_estimators=100, validation_fraction=0.1; total time= 1.1min
# [CV] END criterion=friedman_mse, max_depth=9, max_features=21, min_samples_leaf=10, n_estimators=150, validation_fraction=0.1; total time= 6.7min
# [CV] END criterion=squared_error, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time= 2.6min
# [CV] END criterion=friedman_mse, max_depth=5, max_features=sqrt, min_samples_leaf=7, n_estimators=150, validation_fraction=0.3; total time=  54.3s
# [CV] END criterion=friedman_mse, max_depth=5, max_features=21, min_samples_leaf=8, n_estimators=100, validation_fraction=0.1; total time= 2.6min
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=1, random_state=42, test_size=0.2, train_size=None),
#                    estimator=GradientBoostingClassifier(), n_iter=100,
#                    param_distributions={'criterion': ['friedman_mse',
#                                                       'squared_error'],
#                                         'max_depth': [5, 7, 9],
#                                         'max_features': ['sqrt', 21],
#                                         'min_samples_leaf': [7, 8, 9, 10],
#                                         'n_estimators': [100, 150, 200],
#                                         'validation_fraction': [0.1, 0.2, 0.3]},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
rand_search4.best_params_
# Out:
# {'validation_fraction': 0.1,
#  'n_estimators': 200,
#  'min_samples_leaf': 8,
#  'max_features': 21,
#  'max_depth': 9,
#  'criterion': 'friedman_mse'}

# %%
# Let's look at performance on test set
model_gb = rand_search4.best_estimator_
model_gb.fit(X_train, y_train)
a4 = model_gb.score(X_test, y_test)

# %%
# Let's look at Cross Validation score
model_gb = rand_search4.best_estimator_
b4 = cross_val_score(model_gb, X, y, cv=5, scoring='accuracy')
b4
# Out:
# array([0.6903 , 0.693  , 0.69855, 0.6938 , 0.7014 ])

# %%
print('Mean Accuracy from Cross Validation =',np.mean(b4))
a.loc[len(a.index)] = ['Gradient Boosting', round(a4, 2), round(np.mean(b4), 2)]
# Out:
# Mean Accuracy from Cross Validation = 0.6954100000000001

# %%
a
# Out:
#                Model  Performance on Sub-Test set  \
# 0      Random Forest                         0.71
# 1  Gradient Boosting                         0.81
#
#    Accuracy of CV on Entire Train set
# 0                                0.71
# 1                                0.70

# %% [markdown]
# # THE END
